# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
X1 = np.array([30,30,40, 40])
Y1 = np.array([37, 47, 50, 60])
x2 = np.array([30,30,40, 40, 20, 20, 50, 50])
y2 = np.array([37, 47, 50, 60, 25, 35, 62, 72])
X3 = np.array([30,30,40, 40, 20, 20, 50, 50, 10, 10, 60, 60])
Y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])

# %%
plt.scatter(X1, Y1)
plt.title('Graph to be alanyzed')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
np.corrcoef(X1,Y1)
# Out:
# array([[1.        , 0.79262399],
#        [0.79262399, 1.        ]])

# %%
X1 = X1.reshape(-1,1)
Y1 = Y1.reshape(-1,1)

# %%
model = LinearRegression()
model.fit(X1, Y1)
r_sq = model.score(X1, Y1)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.6282527881040892
# intercept: [3.]
# slope: [[1.3]]

# %%
plt.scatter(X1, Y1)
plt.plot(X1, 3+1.3*X1)
plt.show()

# %%
plt.scatter(x2, y2)
plt.title('Graph to be alanyzed')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
np.corrcoef(x2,y2)
# Out:
# array([[1.        , 0.94058229],
#        [0.94058229, 1.        ]])

# %%
x2 = x2.reshape(-1,1)
y2 = y2.reshape(-1,1)

# %%
model = LinearRegression()
model.fit(x2, y2)
r_sq = model.score(x2, y2)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.8846950517836594
# intercept: [5.1]
# slope: [[1.24]]

# %%
plt.scatter(x2, y2)
plt.plot(x2, 5.1+1.24*x2)
plt.show()

# %%
plt.scatter(X3, Y3)
plt.title('Graph to be alanyzed')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
np.corrcoef(X3,Y3)
# Out:
# array([[1.       , 0.9725791],
#        [0.9725791, 1.       ]])

# %%
X3 = X3.reshape(-1,1)
Y3 = Y3.reshape(-1,1)

# %%
model = LinearRegression()
model.fit(X3, Y3)
r_sq = model.score(X3, Y3)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.9459101071621309
# intercept: [5.6]
# slope: [[1.22571429]]

# %%
plt.scatter(X3, Y3)
plt.plot(X3, 5.6+1.26*X3)
plt.show()

# %%
# чем больше данных, тем выше зависимость (коэффциент корреляции)

# %%
x = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68 ])

# %%
plt.scatter(x, y)
plt.show()

# %%
x = x.reshape(-1,1)
y = y.reshape(-1,1)

# %%
model = LinearRegression()
model.fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.6665424595087748
# intercept: [3.00009091]
# slope: [[0.50009091]]

# %%
plt.scatter(x, y)
plt.plot(x, 3+0.5*x)
plt.show()

# %%
y_hat = 3+0.5*x 
y_hat
# Out:
# array([[ 8. ],
#        [ 7. ],
#        [ 9.5],
#        [ 7.5],
#        [ 8.5],
#        [10. ],
#        [ 6. ],
#        [ 5. ],
#        [ 9. ],
#        [ 6.5],
#        [ 5.5]])

# %%
y_hat = y_hat.reshape(1,-1)
y_hat
# Out:
# array([[ 8. ,  7. ,  9.5,  7.5,  8.5, 10. ,  6. ,  5. ,  9. ,  6.5,  5.5]])

# %%
y = y.reshape(1,-1)

# %%
residuals = y - y_hat
residuals
# Out:
# array([[ 0.04, -0.05, -1.92,  1.31, -0.17, -0.04,  1.24, -0.74,  1.84,
#         -1.68,  0.18]])

# %%
stats.shapiro(residuals)
# Out:
# ShapiroResult(statistic=0.9420998096466064, pvalue=0.545490026473999)

# %%
plt.scatter(y_hat, residuals)
plt.plot(y_hat, residuals)
plt.show()

# %%
x = x.reshape(1,-1)

# %%
plt.scatter(x, residuals)
plt.plot(x, residuals)
plt.show()

# %%
x2 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
y2 = np.array([ 9.14, 8.14, 8.74,8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])
plt.scatter(x2,y2)
plt.show()

# %% [markdown]
# # Домашнее задание

# %% [markdown]
# ## Задание 1.
# Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks): zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110], ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832]. Используя математические операции, посчитать коэффициенты линейной регрессии, приняв за X заработную плату (то есть, zp - признак), а за y - значения скорингового балла (то есть, ks - целевая переменная). Произвести расчет как с использованием intercept, так и без.

# %%
X = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])

# %%
Y = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
n=len(X)

# %%
b=(np.mean(X*Y)-np.mean(X)*np.mean(Y))/(np.mean(X**2)-np.mean(X)**2)

# %%
a=np.mean(Y)-b*np.mean(X)

# %%
b
# Out:
# 2.620538882402765

# %%
a
# Out:
# 444.1773573243596

# %%
X = X.reshape(-1,1)
X
# Out:
# array([[ 35],
#        [ 45],
#        [190],
#        [200],
#        [ 40],
#        [ 70],
#        [ 54],
#        [150],
#        [120],
#        [110]])

# %%
Y = Y.reshape(-1,1)
Y
# Out:
# array([[401],
#        [574],
#        [874],
#        [919],
#        [459],
#        [739],
#        [653],
#        [902],
#        [746],
#        [832]])

# %%
B = np.dot(np.linalg.inv(np.dot(X.T,X)),X.T@Y)
B
# Out:
# array([[5.88982042]])

# %%
X = np.hstack([np.ones((len(X),1)),X])
X
# Out:
# array([[  1.,  35.],
#        [  1.,  45.],
#        [  1., 190.],
#        [  1., 200.],
#        [  1.,  40.],
#        [  1.,  70.],
#        [  1.,  54.],
#        [  1., 150.],
#        [  1., 120.],
#        [  1., 110.]])

# %%
B = np.dot(np.linalg.inv(np.dot(X.T,X)),X.T@Y)
B
# Out:
# array([[444.17735732],
#        [  2.62053888]])

# %% [markdown]
# ## Задание 2.
# Посчитать коэффициент линейной регрессии при заработной плате (zp), используя градиентный спуск (без intercept).

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
zp
# Out:
# array([ 35,  45, 190, 200,  40,  70,  54, 150, 120, 110])

# %%
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])
ks
# Out:
# array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
def mse(B1,y=y, X=X, n=10):
    return np.sum((B1*X - Y)**2)/n

# %%
B1 = 0.1

# %%
alpha = 1e-6
alpha
# Out:
# 1e-06

# %%
for i in range (10000):
    B1 -=alpha*(2/n)*np.sum((B1*zp-ks)*zp)
    if i%5000 == 0:
        print('Iteration: (i), B1={B1}, mse = {mse}'.format(i=i,B1=B1,mse=mse(B1)))
# Out:
# Iteration: (i), B1=0.25952808, mse = 1027296.2106415365
# Iteration: (i), B1=5.889820420132673, mse = 582616.0813677964

# %%
B1 = 0.1

# %%
B0=0.1

# %%
def mse_(B0,B1,y=y, X=X, n=10):
    return np.sum((B0+B1*X - Y)**2)/n

# %%
for i in range (3500000):
    y_pred = B0+B1*zp
    B0 -=alpha*(2/n)*np.sum((y_pred - zp))
    B1 -=alpha*(2/n)*np.sum((y_pred - zp)*ks)
    if i%300000 == 0:
        print('Iteration: {i}, B0={B0}, B1={B1}, mse = {mse}'.format(i=i,B0=B0,B1=B1,mse=mse_(B0,B1)))
# Out:
# Iteration: 0, B0=0.10018232, B1=0.24591308, mse = 1029150.8058729137
# Iteration: 300000, B0=0.09450252949641307, B1=0.9991732063907668, mse = 918791.7823093854
# Iteration: 600000, B0=0.08831499798518476, B1=0.9992273405132889, mse = 918800.7135364234
# Iteration: 900000, B0=0.08253259368490279, B1=0.9992779302165165, mse = 918809.0600808186
# Iteration: 1200000, B0=0.07712879098406021, B1=0.9993252075704923, mse = 918816.860213462
# Iteration: 1500000, B0=0.07207880102950535, B1=0.9993693894505262, mse = 918824.1497008698
# Iteration: 1800000, B0=0.06735945801257119, B1=0.9994106785320669, mse = 918830.9619689779
# Iteration: 2100000, B0=0.0629491129006178, B1=0.9994492642204343, mse = 918837.328256236
# Iteration: 2400000, B0=0.05882753412646363, B1=0.9994853235196783, mse = 918843.2777566984
# Iteration: 2700000, B0=0.05497581478016834, B1=0.999519021844549, mse = 918848.8377537603
# Iteration: 3000000, B0=0.051376285877394685, B1=0.9995505137793038, mse = 918854.0337451553
# Iteration: 3300000, B0=0.04801243530651384, B1=0.999579943786831, mse = 918858.8895597818
